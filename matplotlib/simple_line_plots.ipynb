# %% [markdown]
# # Simple Line Plots
#
# Perhaps the simplest of all plots is the visualization of a single function $y=f(x)$. Here we will take a first look at creating a simple plot of this type. As with all the following sections, we'll start by setting up the notebook for plotting and importing the packgaes we will use:

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# For all Matplotlib plots, we start by creating a figure and an axes. In their simplest form, a figure and axes can be created as follows:

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the *figure* *an instance of the class `plt.figure`) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels. The *axes* (an isntance of the class `plt.Axes`) is what we see above: a bounding obx with ticks and labels, which will eventually contain the plot elements that make up our visualization. Throughout this book, we'll commonly use the variable name `fig` to refer toa figure instance, and `ax` to refer an axes instance or group of axes instances.
#
# Once we have crated and axes, we can use the `ax.plot` function to plot some data. Let's start with a simple sinusoid:

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %% [markdown]
# Alternatively, we can use the pylab interface and let the figure and axes be created for us in the background.

# %%
plt.plot(x, np.sin(x));

# %% [markdown]
# If we want to create a single figure with multiple lines, we can simply call the `plot` function multiple times:

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# that's all there is to plotting simple functions in Matplotlib! We'll nwo dive into some more details about how to control the appearance of the axes and lines.

# %% [markdown]
# ## Adjusting the Plot: Line Colors and Styles
#
# The first adjustment you might wish to make a plot is to control the line colors and styles. The `plt.plot()` function takes additional arguments that can be used to specify these. To adjust he color, you can use the `color` keyword. which accepts a string argument representing virtually any imaginable color. The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0, 0.2, 0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse') # all HTML color names support

# %% [markdown]
# If no color is specified, Matplotlib willa utomatically cycle through a set of default colors for multiple lines.
#
# Similarly, the line style canbe adjusted using the `linestyle` keyword:

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %% [markdown]
# These single-character color codes reflect the standard abbreviations in the RGB (Red/Green/Blue) and CMYK(Cyan/Magenta/Yellow/Black) color systems, commonly used for digital color graphics.
#
# There are many other keyword arguments that can be used to fine-tune the appearance fo the plot; for more details, I'd suggested viewing the dosctring othe `plt.plot()` function using IPython's help tools.

# %% [markdown]
# ## Adjusting the Plot: Axes Limits
#
# Matplotlib does a decent job of choosign default axes limits for yoru plot, but sometimes it's nice to have finer control. The most basic way to adjust axis limit is to use the `plt.xlim()` and `plt.lim()` methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %% [markdown]
# If for some reason you'd like either axis to be displaying in reverse, you can simply reverse the order of the arguments:

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is `plt.axis()` (note her ethe potential cunfsion between *axes with an *e*, and *axis* with an *i*). the `plt.axis()` method allwos you to set the `x` and `y` limits with a single call, by passing a list which specifies `[xmin, xmax, ymin, ymax]`:

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# The `plt.axis()` method goes even beyon this, allowing you to do things like automatically tighten the bounds around the current plot:

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %% [markdown]
# It allows even higher-level specifications, such as ensuring an equal aspect ratio so that on your screen, one unit in `x` is equal to one unit in `y`:

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# ## Labeling Plots
#
# As the last piece of this section, we'll briefly look at hte labeling of plots: titles, axis lables, and simple legends.
#
# Titles and axis labels are the simplest such labels - there are methods that can be used to quickly set them:

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# The position, size, and style of these labels can be adjusted using optional arguments to the function. For more information, see the Matplotlib documentation and the dosctrings of each of these functions.

# %% [markdown]
# When multiple lines are being shown wihtin a single axes, it can be useful to create a plot legend that labels each line type. Again, Matplotlib has a built-in way of quickly creating such a legend. It is done via the (you guessed it) `plt.legend()` method. Though there are several valid ways of suing this, I find it easiest to specify the label of each line using the `label` keyword of the plot function:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.sin(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();

# %% [markdown]
# As you can see, the `plt.legend()` function keeps track of the line style and color, and matches these with the correct label. More information on specifying and formatting plot legends can be found in the `plt.legend` docstring;
