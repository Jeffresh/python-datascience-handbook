# %% [markdown]
# # Simple Scatter Plots
#
# Another comonly used plot type is hte simple scatter plot, a close cousing of the line plot. Instad of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ## Scatter Plots with `plt.plot`

# %% [markdown]
# In the previous section we looked at `plt.plot`/`ax.plot` to produce line plots. It turns out that this same function can produce scatter plots as well

# %%
x = np.linspace(0, 10 , 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %% [markdown]
# The third argument in the functio ncall is a character that represents the type of symbol used for the plotting. Just as you can specify options such as `'-'`, `'--'` to control the line style, the marker style has it own set of short string codes.

# %%
rng = np.random.RandomState(0)

for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, label=f"marker '{marker}' ")
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# For even more possibilites, these caracter codes can be used together with line and color codes to plot points along with a line connecting them:

# %%
plt.plot(x, y , '-ok');

# %% [markdown]
# Additional keyword arguments to `plt.plot` specify a wide range of properties of the lines and markers:

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=10, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)

plt.ylim(-1.2, 1.2);

# %% [markdown]
# This type of flexibility in the `plt.plot` function allows for a wide variety of possible visualization options. For a full description of the options available, refer to the `plt.plot` documentation.
